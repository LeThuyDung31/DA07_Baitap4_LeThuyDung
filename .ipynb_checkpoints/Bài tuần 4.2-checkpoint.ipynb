# %%
import csv
csv_path = "C:\\Users\\Admin\\Desktop\\btnop\\supermarket_sales_vn.csv"
city = []
gender = []

price = []
price_nam = []
price_nu = []
price_HCM = []
price_DN = []
price_HN = []

rating = []
rating_nam = []
rating_nu = []
rating_HCM = []
rating_HN = []
rating_DN = []

product = []

with open(csv_path, mode='r', encoding="utf-8", newline='') as f:
    
    f_csv = csv.reader(f)
    header = next(f_csv)
    for i, row in enumerate(f_csv):
        city.append(row[1])
        gender.append(row[3])
        price.append(float(row[12]))
        rating.append(float(row[13]))
        product.append(row[4])
        if row[3] == "Nam":price_nam.append(float(row[12])), rating_nam.append(float(row[13]))
        if row[3] == "Nữ":price_nu.append(float(row[12])),rating_nu.append(float(row[13]))
        if row[1] == "TP HCM": price_HCM.append(float(row[12])), rating_HCM.append(float(row[13]))
        if row[1] == "Hà Nội": price_HN.append(float(row[12])), rating_HN.append(float(row[13]))        
        if row[1] == "Đà Nẵng": price_DN.append(float(row[12])), rating_DN.append(float(row[13]))

# %%
count_HN = 0
count_TPHCM = 0
count_DANANG = 0 
for tp in city:
    if tp == "Hà Nội": 
        count_HN += 1
    elif tp == "TP HCM":
        count_TPHCM += 1
    elif tp == "Đà Nẵng":
        count_DANANG += 1
print("Hà Nội:",count_HN)
print("TP HCM:",count_TPHCM)
print("Đà Nẵng:",count_DANANG)
# Out:
# Hà Nội: 274
# TP HCM: 490
# Đà Nẵng: 236

# %%
count_nam = 0
count_nu = 0
for i in gender :
    if i == "Nam":
        count_nam += 1
    else:
        count_nu += 1
print ("Nam:",count_nam)
print ("Nữ:", count_nu)
# Out:
# Nam: 499
# Nữ: 501

# %%
import matplotlib
import matplotlib.pyplot as plt
#print(matplotlib)
from matplotlib import pyplot as plt

# %% [markdown]
# ### Tần số

# %%
#tần số thành phố
ds_city = [count_HN,count_TPHCM,count_DANANG]
ds_gender = [count_nam,count_nu]

label_city = ["Hà Nội","Hồ Chí Minh","Đà Nẵng"]
fig = plt.figure(figsize=(10,8))
ax1 = fig.add_subplot(2,2,1)
ax1.bar(x=range(len(ds_city)),height= ds_city,width=0.4)
ax1.set_xticks(range(len(label_city)),label_city)
ax1.set_title("Biểu đồ thể hiện tần số địa phương",size=10,weight="bold")
for index in range(len(ds_city)):
    ax1.text((index-0.15),(ds_city[index]-50),ds_city[index],size=14,color="w",fontweight="bold")

#tần số gender
label_gender = ["Nam","Nữ"]    
ax2 = fig.add_subplot(2,2,2)  
ax2.bar(x=range(len(ds_gender)),height=ds_gender,width=0.3,color="pink")
ax2.set_xticks(range(len(label_gender)),label_gender) 
ax2.set_title("Biểu đồ thể hiện tần số giới tính",size=10,weight="bold")
for index in range(len(ds_gender)):
    ax2.text((index-0.1),(ds_gender[index]-55),ds_gender[index],size=14,color="brown",fontweight="bold")

plt.show()

# %%
fig = plt.figure(figsize=(10,8))
ax1 = fig.add_subplot(2,2,1)
labels = label_city
ax1.pie((ds_city), autopct="%.1f%%",
        shadow= True,
        explode=[0.1,0,0],
        colors=["cyan","pink","lightgreen"])
ax1.set_title("Biểu đồ tròn thể hiện tần số địa phương",size=10,weight="bold",color="orchid")
plt.legend(labels, loc=[0.78,0.7])

ax2 = fig.add_subplot(2,2,2)
ax2.pie(ds_gender,labels=label_gender, autopct='%1.1f%%',
        colors=["cyan","pink"],
       
        shadow=True, 
        startangle=90)
ax2.set_title("Biểu đồ tròn thể hiện tần số giới tính",size=10,weight="bold",color="cyan",)
plt.legend(label_gender, loc=[0.78,0.7])
plt.show()

# %% [markdown]
# ## Tần suất

# %%
tan_suat_city = []
tan_suat_gender = []
for i in set(city):
    count = 0
    for x in city:
        if x == i: count += 1
    ty_le = count*100/len(city)
    tan_suat_city.append(ty_le)
for i in set(gender):
    count = 0
    for y in gender:
        if y == i: count += 1
    ty_le = count*100/len(gender)
    tan_suat_gender.append(ty_le)
tan_suat_city
tan_suat_gender
# Out:
# [49.9, 50.1]

# %%
#tần suất thành phố
fig = plt.figure(figsize=(10,7)) 
ax3 = fig.add_subplot(2,2,3)
label_city_tsuat= ["Hà Nội","Đà Nẵng","Hồ Chí Minh"]
ax3.bar(x=range(len(tan_suat_city)),height=tan_suat_city,color="Magenta",width=0.5,edgecolor = "k")
ax3.set_xticks(range(3),label_city_tsuat)
ax3.set_title("Biểu đồ cột thể hiện tần suất địa phương",size=10,fontweight="bold",color="black",)
for index in range(len(tan_suat_city)):
    ax3.text((index-0.2),(tan_suat_city[index]-5),tan_suat_city[index],size=14,color="w",fontweight="bold")

#tần suất giới tính    
ax4 = fig.add_subplot(2,2,4)
ax4.bar(x=range(len(tan_suat_gender)),height=tan_suat_gender,color="Magenta",width=0.5,edgecolor = "k")
ax4.set_xticks(range(2),label_gender)
ax4.set_title("Biểu đồ cột thể hiện tần suất giới tính",size=10,fontweight="bold",color="black",)
for index in range(len(tan_suat_gender)):
    ax4.text((index-0.1),(tan_suat_gender[index]-5),tan_suat_gender[index],size=14,color="w",fontweight="bold")
plt.show()

# %% [markdown]
# #### Từ biểu đồ trên ta thấy được:
# * Số đơn hàng cao nhất đến từ Thành phố Hồ Chí Minh và chiếm 49% trên tổng đơn hàng
# * Tổng số đơn hàng của nữ chiếm cao hơn của nam 0.2%

# %%
import matplotlib
import matplotlib.pyplot as plt
import squarify
import csv

# %%
fig = plt.figure(figsize=(10,3))
ax1 = fig.add_subplot(1,2,1)
ax1.hist(price,bins=10,
        facecolor="SteelBlue", edgecolor='k',
        align="mid",)
ax1.set_title("Biểu đồ thể hiện phân bố COGS",size=9,weight="bold",color="black")
plt.grid(linestyle="--", linewidth=0.6,alpha=0.5)

ax2 = fig.add_subplot(1,2,2)
ax2.hist(rating,bins=10,
        facecolor='lightgreen', edgecolor='k',
        align="mid",)
ax2.set_title("Biểu đồ thể hiện phân bố Rating",size=9,weight="bold",color="black",)
plt.grid(linestyle="--", linewidth=0.6,alpha=0.5)

# %% [markdown]
# ### Từ biểu đồ phân bố trên ta thấy:
# * COGS cao nhất từ 0 đến 200
# * Rating cao nhất là từ 6.5 đến 7

# %%
fig =plt.figure(figsize=(10,7))
ax3 = fig.add_subplot(2,2,1)
ax3.hist(price_nam,bins=30,
        facecolor="RoyalBlue", edgecolor='k',alpha=0.75,
        align="mid",)
ax3.hist(price_nu,bins=30,
        facecolor="pink", edgecolor='k',alpha=0.8,
        align="mid",)
ax3.legend(["Nam", "Nữ"])
ax3.set_title("Biểu đồ thể hiện phân bố COGS theo giới tính",size=9,color="black",)
plt.grid(linestyle="--", linewidth=0.5,alpha=0.5)


ax4 = fig.add_subplot(2,2,2)
ax4.hist(price_HCM,bins=10,
        facecolor="MediumSpringGreen", edgecolor='k',alpha=0.75,
        align="mid",)
ax4.hist(price_HN,bins=10,
        facecolor="red", edgecolor='k',alpha=0.75,
        align="mid",)
ax4.hist(price_DN,bins=10,
        facecolor='RoyalBlue', edgecolor='k',alpha=0.75,
        align="mid",)
ax4.legend(["Hồ Chí Minh", "Hà Nội", "Đà Nẵng"])
ax4.set_title("Biểu đồ thể hiện phân bố COGS theo địa phương",size=9,color="black",)
plt.grid(linestyle="--", linewidth=0.5,alpha=0.75)

ax5 = fig.add_subplot(2,2,4)
ax5.hist(rating_HCM,bins=20,
        facecolor='RoyalBlue', edgecolor='k',alpha=0.75,
        align="mid",)
ax5.hist(rating_HN,bins=20,
        facecolor='peachpuff', edgecolor='k',alpha=0.75,
        align="mid",)
ax5.hist(rating_DN,bins=20,
        facecolor='orange', edgecolor='k',alpha=0.75,)
ax5.legend(["Hồ Chí Minh", "Hà Nội", "Đà Nẵng"],loc="upper right",ncols=3,fontsize=8,)
ax5.set_title("Biểu đồ thể hiện phân bố Rating theo địa phương",size=9,color="black",)

ax6 =fig.add_subplot(2,2,3)
ax6.hist(rating_nam,bins=10,
        facecolor='RoyalBlue', edgecolor='k',alpha=0.75,
        align="mid",)
ax6.hist(rating_nu,bins=10,
        facecolor='pink', edgecolor='k',alpha=0.75,
        align="mid",)
ax6.legend(["Nam", "Nữ"])
ax6.set_title("Biểu đồ thể hiện phân bố Rating theo giới tính",size=9,color="black",)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Từ biểu đồ phân bố COGS trên ta có thể thấy được:
# * Giới tính nam và nữ từ 0 đến 200 xuất hiện nhiều nhất
# * 3 địa phương cũng xuất hiện nhiều nhất ở giá trị từ 0 đến 200
# ### Biểu đồ phân bố Rating ta thấy:
# * Nam xuất hiện nhiều nhất từ 5.7 đến 6.4
#   Nữ xuất hiện nhiều nhất từ 4 đến 4.6
# * Thành phố Hồ Chí Minh xuất hiện cao nhất, kế đến là Hà Nội và Đà Nẵng.

# %%
plt.scatter(price,rating)
plt.show()

# %% [markdown]
# ## Tree-map

# %%
import squarify
import csv

# %%
print(set(product))
# Out:
# {'Fashion accessories', 'Sports and travel', 'Food and beverages', 'Home and lifestyle', 'Health and beauty', 'Electronic accessories'}

# %%
product_line=[product.count("Home and lifestyle"),
            product.count("Food and beverages"),
            product.count("Sports and travel"),
            product.count("Health and beauty"),
            product.count("Fashion accessories"),
            product.count("Electronic accessories")]
labels_product = ["Home and lifestyle\n" + str(product_line[0]),
"Food and beverages\n"+ str(product_line[1]),
"Sports and travel\n" + str(product_line[2]),
"Health and beauty\n"+ str(product_line[3]),
"Fashion accessories\n"+ str(product_line[4]),
"Electronic accessories\n"+ str(product_line[5])]

# %%
fig = plt.figure(figsize=(7,4))
squarify.plot(sizes=product_line,label=labels_product,color=["Violet","SpringGreen","lightpink","coral","DodgerBlue","w"])
plt.axis("off")
plt.plot()
plt.show()
